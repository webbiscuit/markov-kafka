# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm
import spacy
import markovify
import re

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# %%
from urllib import request

url = "https://www.gutenberg.org/files/5200/5200-0.txt"

response = request.urlopen(url)
raw = response.read()
text = raw.decode("utf-8-sig")

# %%
def strip_gutenberg_burger(text):
    lines = re.split(r"[~\r\n]+", text)

    book = []
    in_book = False
    for line in lines:

        if line.startswith("*** END OF THE PROJECT GUTENBERG EBOOK"):
            in_book = False

        if in_book:
            book.append(line)

        if line.startswith("*** START OF THE PROJECT GUTENBERG EBOOK"):
            in_book = True
        
    return " ".join(book)

text = strip_gutenberg_burger(text)

# %%
def text_cleaner(text):
    text = text.replace("“","\"")
    text = text.replace("’","'")

    return text

text = text_cleaner(text)

# %%
doc = nlp(text)

# %%
# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Noun phrases: ['Metamorphosis', 'Franz Kafka', 'David Wyllie', 'I', 'Gregor Samsa', 'troubled dreams', 'he', 'himself', 'his bed', 'a horrible vermin', 'He', 'he', 'his head', 'he', 'his brown belly', 'arches', 'stiff sections', 'it', 'any moment', 'His many legs', 'the size', 'the rest', 'him', 'he', 'What', 'me', 'he', 'It', 'a dream', 'His room', 'a proper human room', 'its four familiar walls', 'A collection', 'textile samples', 'the table', 'Samsa', 'a travelling salesman', 'it', 'a picture', 'he', 'an illustrated magazine', 'a nice, gilded frame', 'It', 'a lady', 'a fur hat', 'fur boa', 'who', 'a heavy fur muff', 'the whole', 'her lower arm', 'the viewer', 'Gregor', 'the window', 'the dull weather', 'Drops', 'rain', 'the pane', 'him', 'I', 'all this nonsense', 'he', 'something', 'he', 'he', 'his right', 'his present state', 'that position', 'he', 'himself', 'his right', 'he', 'he', 'He', 'it', 'his eyes', 'he', 'the floundering legs', 'he', 'a mild, dull pain', 'he', 'he', 'what a strenuous career', 'it', 'I', 'Travelling day', 'business', 'much more effort', 'your own business', 'home', 'top', 'the curse', 'worries', 'train connections', 'bad and irregular food', 'contact', 'different people', 'you', 'anyone', 'them', 'It', 'Hell', 'He', 'a slight itch', 'his belly', 'himself', 'his back', 'the headboard', 'he', 'his head', 'the itch', 'it', 'lots', 'little white spots', 'he', 'what', 'he', 'the place', 'his legs', 'he', 'it', 'he', 'it', 'he', 'a cold shudder', 'He', 'his former position', 'he', 'it', 'you', 'You', 'enough sleep', 'Other travelling salesmen', 'a life', 'luxury', 'instance', 'I', 'the guest house', 'the morning', 'the contract', 'these gentlemen', 'their breakfasts', 'I', 'my boss', 'I', 'the spot', 'who', 'the best thing', 'me', 'I', 'my parents', 'I', 'my notice', 'I', 'the boss', 'him', 'just what', 'I', 'him', 'everything', 'I', 'him', 'just what', 'I', 'He', 'his desk', 'it', 'a funny sort', 'business', 'your desk', 'your subordinates', 'you', 'the boss', 'hearing', 'some hope', 'I', 'the money', "my parents' debt", 'him', 'I', 'what', 'I', 'I', 'the big change', 'I', 'my train', 'he', 'the alarm clock', 'the chest', 'drawers', 'God', 'Heaven', 'he', 'It', 'the hands', 'it', 'quarter', 'the alarm', 'He', 'the bed', 'it', "four o'clock", 'it', 'it', 'it', 'that furniture-rattling noise', 'he', 'What', 'he', 'The next train', 'he', 'he', 'the collection', 'samples', 'he', 'he', 'the train', 'he', "his boss's anger", 'the office assistant', "the five o'clock train", 'he', 'his report', 'Gregor', 'The office assistant', "the boss's man", 'no understanding', 'he', 'five years', 'service Gregor', 'His boss', 'the doctor', 'the medical insurance company', 'his parents', 'a lazy son', "the doctor's recommendation", 'any claim', 'the doctor', 'no-one', 'what', 'he', 'this case', 'Gregor', 'fact', 'excessive sleepiness', 'He', 'the bed', 'the clock', 'quarter', 'a cautious knock', 'the door', 'his head', 'somebody', 'it', 'his mother—"it\'s quarter', 'you', 'That gentle voice', 'Gregor', 'he', 'his own voice', 'it', 'the voice', 'he', 'him', 'a painful and uncontrollable squeaking', 'it', 'the words', 'a sort', 'echo', 'them', 'the hearer', 'he', 'Gregor', 'a full answer', 'everything', 'the circumstances', 'himself', 'you', 'I', 'The change', "Gregor's voice", 'the wooden door', 'his mother', 'this explanation', 'this short conversation', 'the other members', 'the family', 'Gregor', 'their expectations', 'home', 'his father', 'the side doors', 'his fist', 'Gregor', 'Gregor', 'he', 'what', 'he', 'a warning deepness', 'his voice', 'Gregor', 'Gregor', 'the other side door', 'his sister', 'Gregor', 'you', 'you', 'anything', 'Gregor', 'both sides', 'I', 'an effort', 'all the strangeness', 'his voice', 'long pauses', 'each, individual word', 'His father', 'his breakfast', 'his sister', 'Gregor', 'the door', 'I', 'you', 'Gregor', 'no thought', 'the door', 'himself', 'his cautious habit', 'all doors', 'night', 'he' ...
# Verbs: ['translate', 'wake', 'find', 'transform', 'lie', 'lift', 'see', 'dome', 'divide', 'bed', 'cover', 'seem', 'slide', 'compare', 'wave', 'look', 'happen', 'think', 'lie', 'lie', 'spread', 'travel', 'hang', 'cut', 'house', 'show', 'fit', 'sit', 'raise', 'cover', 'turn', 'look', 'hear', 'hit', 'make', 'feel', 'sleep', 'forget', 'think', 'be', 'be', 'do', 'use', 'sleep', 'get', 'throw', 'roll', 'be', 'try', 'shut', 'have', 'look', 'flounder', 'stop', 'begin', 'feel', 'feel', 'think', 'choose', 'travel', 'do', 'take', 'do', 'be', 'travel', 'make', 'get', 'know', 'become', 'go', 'feel', 'push', 'lift', 'find', 'see', 'cover', 'know', 'make', 'try', 'feel', 'draw', 'touch', 'overcome', 'slide', 'get', 'think', 'make', 'get', 'get', 'travel', 'live', 'go', 'copy', 'sit', 'eat', 'try', 'kick', 'know', 'be', 'have', 'think', 'give', 'go', 'tell', 'think', 'tell', 'let', 'know', 'feel', 'fall', 'sit', 'talk', 'have', 'go', 'be', 'get', 'pay', 'suppose', 'do', 'make', 'get', 'get', 'leave', 'look', 'tick', 'think', 'move', 'see', 'set', 'be', 'ring', 'sleep', 'rattle', 'sleep', 'do', 'go', 'be', 'catch', 'have', 'rush', 'be', 'pack', 'feel', 'catch', 'avoid', 'be', 'see', 'go', 'put', 'be', 'report', 'be', 'be', 'come', 'accuse', 'have', 'accept', 'make', 'believe', 'be', 'be', 'be', 'sleep', 'feel', 'feel', 'think', 'decide', 'get', 'strike', 'call', 'want', 'go', 'shock', 'hear', 'answer', 'recognise', 'have', 'be', 'mix', 'make', 'be', 'make', 'leave', 'hear', 'want', 'give', 'explain', 'content', 'say', 'get', 'notice', 'be', 'shuffle', 'make', 'come', 'knock', 'call', 'call', 'come', 'need', 'answer', 'be', 'make', 'remove', 'enunciate', 'put', 'go', 'whisper', 'open', 'beg', 'have', 'open', 'congratulate', 'acquire', 'travel', 'lock', 'be', 'want', 'do', 'get', 'disturb', 'dress', 'have', 'consider', 'do', 'be', 'bring', 'lie', 'remember', 'feel', 'cause', 'lie', 'turn', 'be', 'wonder', 'resolve', 'have', 'be', 'be', 'travel', 'throw', 'have', 'blow', 'fall', 'become', 'be', 'use', 'push', 'have', 'move', 'be', 'control', 'want', 'bend', 'stretch', 'manage', 'do', 'want', 'seem', 'set', 'move', 'do', 'say', 'keep', 'try', 'do', 'want', 'do', 'get', 'see', 'imagine', 'look', 'turn', 'be', 'move', 'go', 'shove', 'gather', 'choose', 'hit', 'learn', 'burn', 'feel', 'be', 'try', 'get', 'turn', 'manage', 'follow', 'get', 'occur', 'let', 'fall', 'be', 'injure', 'become', 'carry', 'push', 'knock', 'stay', 'lose', 'take', 'get', 'be', 'lie', 'watch', 'struggle', 'be', 'think', 'bring', 'tell', 'stay', 'do', 'be', 'get', 'forget', 'remind', 'rush', 'direct', 'look', 'envelop', 'have', 'offer', 'say', 'strike', 'be', 'lie', 'breathe', 'expect', 'bring', 'say', 'strike', 'have', 'get', 'come', 'ask', 'happen', 'open', 'set', 'swinge', 'succeed', 'fall', 'keep', 'raise', 'do', 'avoid', 'injure', 'seem', 'be', 'happen', 'fall', 'bind', 'make', 'raise', 'have', 'risk', 'stick', 'have', 'do', 'occur', 'be', 'come', 'help', 'have', 'be', 'have', 'push', 'peel', 'bend', 'be', 'swang', 'find', 'call', 'lock', 'be', 'suppress', 'move', 'be', 'keep', 'rock', 'have', 'make', 'be', 'say', 'freeze', 'become', 'dance', 'remain', 'open', 'say', 'catch', 'go', 'open', 'need', 'hear', 'know', 'have', 'be', 'condemn', 'work', 'become', 'be', 'be', 'go', 'get', 'spend', 'be', 'let', 'make', 'assume', 'have', 'come', 'have', 'show', 'trust', 'have', 'investigate', 'make', 'swang', 'be', 'soften', 'be', 'think', 'make', 'muffle', 'hold', 'hit', 'fall', 'turn', 'rub', 'fall', 'say', 'try', 'imagine', 'happen', 'happen', 'have', 'concede', 'hear', 'whisper', 'let', 'know', 'know', 'say', 'dare', 'raise', 'hear', 'say', 'come', 'want', 'know', 'leave', 'know', 'say', 'want', 'speak', 'open', 'be', 'be', 'forgive', 'call', 'say', 'continue', 'speak', 'believe', 'miss', 'think', 'make', 'cross', 'go', 'be', 'stay', 'sit', 'read', 'train', 'work', 'make', 'take', 'be', 'hang', 'see', 'open', 'be', 'be', 'be', 'get', 'open', 'be', 'say', 'be', 'be', 'say', 'move',  ...

# %%
# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Franz Kafka Translated PERSON
# David Wyllie PERSON
# One morning TIME
# Gregor Samsa PERSON
# four CARDINAL
# Samsa PRODUCT
# Gregor PERSON
# a hundred CARDINAL
# one CARDINAL
# morning TIME
# First ORDINAL
# five CARDINAL
# half past six DATE
# more like quarter DATE
# seven CARDINAL
# four o'clock TIME
# seven CARDINAL
# Gregor PERSON
# five years DATE
# Gregor PERSON
# quarter DATE
# seven CARDINAL
# Gregor PERSON
# seven CARDINAL
# Gregor PERSON
# first ORDINAL
# Gregor PERSON
# Gregor GPE
# Gregor PERSON
# Gregor GPE
# first ORDINAL
# today DATE
# first ORDINAL
# first ORDINAL
# Gregor PERSON
# first ORDINAL
# first ORDINAL
# morning TIME
# seven o'clock TIME
# quarter past DATE
# seven CARDINAL
# seven o'clock TIME
# Gregor PERSON
# half CARDINAL
# Two CARDINAL
# ten past seven DATE
# Gregor PERSON
# Gregor PERSON
# first ORDINAL
# at least a couple of hours CARDINAL
# Gregor PERSON
# Gregor PERSON
# today DATE
# Gregor PERSON
# Gregor PERSON
# morning TIME
# Samsa PERSON
# a week DATE
# every evening TIME
# two or three CARDINAL
# Gregor PERSON
# this morning TIME
# Samsa PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor NORP
# Samsa PERSON
# This morning TIME
# Samsa PERSON
# Gregor PERSON
# last night TIME
# last night TIME
# these few hours TIME
# Gregor PERSON
# Gregor PERSON
# eight o'clock TIME
# first ORDINAL
# Gregor ORG
# Gregor PERSON
# Anna PERSON
# Anna PERSON
# two CARDINAL
# Gregor PERSON
# first ORDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# first ORDINAL
# Gregor PERSON
# two CARDINAL
# Gregor GPE
# only half CARDINAL
# the day DATE
# several hours TIME
# Gregor PERSON
# almost the whole year DATE
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# the years DATE
# Gregor PERSON
# Gregor PERSON
# first ORDINAL
# first ORDINAL
# Gregor better PERSON
# Gregor gently PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor ORG
# Gregor PERSON
# more than one CARDINAL
# one CARDINAL
# Gregor PERSON
# two CARDINAL
# One CARDINAL
# that morning TIME
# only one CARDINAL
# evening TIME
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# one CARDINAL
# the day DATE
# late at night TIME
# Gregor GPE
# five years DATE
# almost before the night TIME
# Gregor PERSON
# Gregor PERSON
# half CARDINAL
# evening TIME
# two days DATE
# Gregor PERSON
# Gregor PERSON
# more than a month earlier DATE
# the day before yesterday DATE
# half CARDINAL
# Half CARDINAL
# Gregor PERSON
# second ORDINAL
# midday TIME
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# first ORDINAL
# today DATE
# Gregor PERSON
# first ORDINAL
# two whole days DATE
# at least two CARDINAL
# the very first day DATE
# a quarter of an hour DATE
# Gregor PERSON
# Gregor PERSON
# the first day DATE
# Gregor PERSON
# five years earlier DATE
# first ORDINAL
# Gregor NORP
# first ORDINAL
# Gregor PERSON
# Gregor PERSON
# almost overnight TIME
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# next year DATE
# Gregor PERSON
# Christmas day DATE
# Gregor ORG
# first ORDINAL
# Gregor PERSON
# the old days DATE
# every month DATE
# Gregor PERSON
# the day DATE
# one CARDINAL
# two years DATE
# the five years DATE
# first ORDINAL
# Gregor PERSON
# every other day DATE
# seventeen CARDINAL
# Gregor GPE
# first ORDINAL
# hours TIME
# Charlottenstrasse ORG
# Gregor PERSON
# Gregor PERSON
# Gregor GPE
# One day DATE
# about a month DATE
# Gregor GPE
# Gregor PERSON
# midday TIME
# One day DATE
# four hours TIME
# the first fourteen days DATE
# Gregor GPE
# two CARDINAL
# Gregor GPE
# Gregor PERSON
# first ORDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# one day DATE
# Gregor PERSON
# Gregor PERSON
# the day DATE
# the few square meters QUANTITY
# sixteen year old DATE
# Gregor PERSON
# First ORDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# fifteen minutes TIME
# one CARDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# these two months DATE
# Gregor PERSON
# first ORDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# two CARDINAL
# first ORDINAL
# Gregor PERSON
# two CARDINAL
# four CARDINAL
# first ORDINAL
# Gregor PERSON
# Grete PERSON
# Grete PERSON
# Grete PERSON
# Grete ORG
# Grete ORG
# Gregor PERSON
# Gregor PERSON
# Grete PERSON
# Gregor PERSON
# Grete ORG
# first ORDINAL
# Grete ORG
# Gregor PERSON
# Grete ORG
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Sunday DATE
# Gregor PERSON
# Gregor PERSON
# the first day DATE
# Gregor PERSON
# one CARDINAL
# Gregor PERSON
# Gregor PERSON
# more than a month DATE
# Gregor PERSON
# Gregor PERSON
# minutes TIME
# every evening TIME
# one CARDINAL
# two hours TIME
# French NORP
# Gregor PERSON
# today DATE
# Gregor PERSON
# Gregor PERSON
# ten CARDINAL
# Gregor PERSON
# six CARDINAL
# a quarter of an hour DATE
# Gregor PERSON
# Gregor PERSON
# two CARDINAL
# two CARDINAL
# Gregor PERSON
# Gregor GPE
# every morning TIME
# Gregor PERSON
# evening TIME
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor ORG
# Grete PERSON
# two CARDINAL
# three CARDINAL
# one CARDINAL
# Gregor PERSON
# midday TIME
# first ORDINAL
# weeks DATE
# Gregor ORG
# Gregor PERSON
# Gregor ill PERSON
# evening TIME
# Gregor GPE
# two CARDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# one day DATE
# Gregor GPE
# early in the morning TIME
# that spring DATE
# Gregor PERSON
# one CARDINAL
# Gregor PERSON
# Gregor PERSON
# a few hours TIME
# first ORDINAL
# three CARDINAL
# three CARDINAL
# Gregor PERSON
# Gregor GPE
# first ORDINAL
# Gregor PERSON
# first ORDINAL
# hours TIME
# evening TIME
# One CARDINAL
# Gregor PERSON
# Gregor PERSON
# two CARDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor GPE
# Gregor PERSON
# this evening TIME
# three CARDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# three CARDINAL
# between two CARDINAL
# one CARDINAL
# Gregor PERSON
# first ORDINAL
# three CARDINAL
# half CARDINAL
# Gregor PERSON
# Gregor PERSON
# last Christmas DATE
# Christmas DATE
# Gregor GPE
# Samsa PERSON
# Gregor ORG
# Gregor PERSON
# three CARDINAL
# first ORDINAL
# two CARDINAL
# Gregor GPE
# three CARDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# three CARDINAL
# three CARDINAL
# Gregor PERSON
# three CARDINAL
# Gregor PERSON
# the days DATE
# two CARDINAL
# Gregor PERSON
# Gregor PERSON
# three CARDINAL
# first ORDINAL
# Gregor PERSON
# Gregor PERSON
# three CARDINAL
# Gregor's PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# Gregor ORG
# Gregor GPE
# half CARDINAL
# Gregor PERSON
# Gregor PERSON
# Gregor PERSON
# three CARDINAL
# early in the morning TIME
# Gregor GPE
# first ORDINAL
# Gregor PERSON
# Samsa PERSON
# Samsa PERSON
# Samsa PERSON
# Grete ORG
# three CARDINAL
# Samsa PERSON
# Samsa PERSON
# Samsa PERSON
# three CARDINAL
# Gregor PERSON
# Samsa PERSON
# Grete PERSON
# early in the morning TIME
# the end of March DATE
# three CARDINAL
# Gregor GPE
# Gregor PERSON
# Samsa PERSON
# one CARDINAL
# Grete ORG
# Samsa PERSON
# the middle of the DATE
# three CARDINAL
# two CARDINAL
# Samsa PERSON
# two CARDINAL
# first ORDINAL
# Samsa PERSON
# Samsa PERSON
# Samsa PERSON
# two CARDINAL
# Samsa PERSON
# three CARDINAL
# premises LOC
# Samsa PERSON
# two CARDINAL
# three CARDINAL
# a few moments later TIME
# Samsa PERSON
# Samsa PERSON
# that day DATE
# three CARDINAL
# Samsa PERSON
# Samsa PERSON
# Grete PERSON
# that morning TIME
# three CARDINAL
# first ORDINAL
# Samsa PERSON
# Samsa PERSON
# Samsa PERSON
# Samsa PERSON
# Grete ORG
# Samsa PERSON
# Tonight TIME
# Samsa PERSON
# Samsa PERSON
# two CARDINAL
# three CARDINAL
# months DATE
# three CARDINAL
# Gregor GPE
# Grete PERSON
# Samsa PERSON
# first ORDINAL

# %%
sents = ' '.join([sent.text for sent in doc.sents if len(sent.text) > 1])

# %%
generator_1 = markovify.Text(sents, state_size=3)

# %%
#We will randomly generate three sentences
for i in range(3):
    print(generator_1.make_sentence())
#We will randomly generate three more sentences of no more than 100 characters
for i in range(3):
    print(generator_1.make_short_sentence(max_chars=1000))
# Out:
# If they were shocked then it would no longer be Gregor's responsibility and he could only hear their feet as they stepped heavily on the floor.
# His sister began to cry.
# Gregor's mother did once thoroughly clean his room, and could not understand how he had behaved this time and whether, perhaps, any slight improvement could be seen.
# Gregor's wish to see his mother was to be up at six to get to work.
# He was merely fixed on the idea that Gregor should be got back into his room, although that was in a position to bear the costs of the whole performance and it was out of the room was alright; and only then did she let her mother dissuade her.
# It seemed remarkable to Gregor that Grete had not said enough and that his father would stop that unbearable hissing!

# %%
#next we will use spacy's part of speech to generate more legible text
class POSifiedText(markovify.Text):
    def word_split(self, sentence):
        return ['::'.join((word.orth_, word.pos_)) for word in nlp(sentence)]
    def word_join(self, words):
        sentence = ' '.join(word.split('::')[0] for word in words)
        return sentence
#Call the class on our text
generator_2 = POSifiedText(sents, state_size=3)

# %%
def tidy(text):
    text = text.replace(" ;", ";")
    text = text.replace(" '", "'")    
    text = text.replace(" ,", ",")    
    text = text.replace(" .", ".")    
    text = text.replace(" ?", "?")    
    return text

# %%
for i in range(5):
    txt = generator_2.make_sentence()
    if txt is not None:
        print(tidy(txt))
# Out:
# So she refused to let her out of his shocked state.
# Whenever they began to talk of the need to earn money in quite different ways.
# But who knows, maybe that was a good sign.
# But now the two of them, then that was the first word she had spoken to him directly since his transformation.

# %%
for i in range(5):
    txt = generator_2.make_short_sentence(max_chars=200)
    if txt:
        print(tidy(txt))
# Out:
# But his sister was not there, Gregor would always first let go of the door and lifted it towards his father.
# Gregor made a run for him; he wanted to say something would invariably stop and gather his companions around him.
# In her alarm, which was something they had not been touched in the meantime and some interest had accumulated.
# This meant that his mother's attention.
# Gregor drew his head back from the door and he would remain immobile for hours afterwards.
